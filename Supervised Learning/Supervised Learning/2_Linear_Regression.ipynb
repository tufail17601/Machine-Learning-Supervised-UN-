# %% [markdown]
# LINEAR REGRESION :

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn import linear_model

# %%
df = pd.read_csv("homeprices.csv")
df
plt.scatter(df.area,df.price,color = "red",marker='o')
plt.xlabel("Area")
plt.ylabel("Prices(USD)")
# Out:
# Text(0, 0.5, 'Prices(USD)')

# %%
plt.scatter(df.area,df.price)
plt.xlabel("Area")
plt.ylabel("Prices")
plt.title("A prediction Model That predict prices")
plt.grid(True)
plt.tight_layout()
plt.plot(df.area,reg.predict(df[['area']]),color = 'r')

# %%
reg = linear_model.LinearRegression()
reg.fit(df[['area']],df['price'])
# Out:
# LinearRegression()

# %%
price = reg.predict([[5000]]).item()
print(f"The predicted price is:{round(price):,}")
# Out:
# The predicted price is:859,555
# c:\Users\yousaf\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
import joblib
joblib.dump(reg,'model_file')
# Out:
# ['model_file']

# %%
pred = joblib.load('model_file')
pred.predict([[3000]])
# Out:
# c:\Users\yousaf\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([587979.45205479])

# %%
d = pd.read_csv("areas.csv")
d

# %%
p = reg.predict(d)
p
# Out:
# array([ 316404.10958904,  384297.94520548,  492928.08219178,
#         661304.79452055,  740061.64383562,  799808.21917808,
#         926090.75342466,  650441.78082192,  825607.87671233,
#         492928.08219178, 1402705.47945205, 1348390.4109589 ,
#        1144708.90410959])

# %%
d['Price'] = p

# %%
d
d.drop('Prices',axis=1,inplace = True)

# %%
d
d.to_csv("Predicted Prices",index=False)

# %%
import joblib
joblib.dump(reg,'model_file')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 2
#       1 import joblib
# ----> 2 joblib.dump(reg,'model_file')
#
# NameError: name 'reg' is not defined
